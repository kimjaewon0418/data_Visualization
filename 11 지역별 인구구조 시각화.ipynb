# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
plt.rcParams['font.family']='Malgun Gothic'
plt.rcParams['axes.unicode_minus']=False

# %% [markdown]
# # 데이터 수집 및 전처리
# * 행정안전부<br>
# https://www.mois.go.kr/<br>
# 정책자료 > 주민등록인구통계<br>
# 전체읍면동 현황<br><br>
# * 바로가기<br>
# https://jumin.mois.go.kr/index.jsp

# %% [markdown]
# ## 데이터프레임 생성 및 전처리

# %% [markdown]
# ### 데이터프레임 생성

# %%
df = pd.read_csv('data/202110_202110_주민등록인구및세대현황_월간.csv', encoding='cp949')
df
# Out:
#                               행정구역 2021년10월_총인구수 2021년10월_세대수  \
# 0              서울특별시  (1100000000)     9,532,428    4,422,587
# 1           서울특별시 종로구 (1111000000)       145,346       73,613
# 2      서울특별시 종로구 청운효자동(1111051500)        12,011        5,252
# 3        서울특별시 종로구 사직동(1111053000)         9,367        4,686
# 4        서울특별시 종로구 삼청동(1111054000)         2,478        1,251
# ...                            ...           ...          ...
# 3847  제주특별자치도 서귀포시 서홍동(5013058000)        10,999        4,517
# 3848  제주특별자치도 서귀포시 대륜동(5013059000)        15,216        6,760
# 3849  제주특별자치도 서귀포시 대천동(5013060000)        13,900        6,474
# 3850  제주특별자치도 서귀포시 중문동(5013061000)        11,886        5,731
# 3851  제주특별자치도 서귀포시 예래동(5013062000)         3,916        2,011
#
#       2021년10월_세대당 인구 2021년10월_남자 인구수 2021년10월_여자 인구수  2021년10월_남여 비율
# 0                2.16       4,630,630       4,901,798            0.94
# 1                1.97          70,552          74,794            0.94
# 2                2.29           5,553           6,458            0.86
# 3                2.00           4,206           5,161            0.81
# 4                1.98           1,178           1,300            0.91
# ...               ...             ...             ...             ...
# 3847             2.44           5,435           5,564            0.98
# 3848             2.25           7,691           7,525            1.02
# 3849             2.15           7,048           6,852            1.03
# 3850             2.07           6,057           5,829            1.04
# 3851             1.95           2,004           1,912            1.05
#
# [3852 rows x 7 columns]

# %% [markdown]
# ### 컬럼명 변경

# %%
df.columns=['행정구역','총인구수','세대수','세대당 인구','남자 인구수','여자 인구수','남여 비율']

# %%
df.head(1)
# Out:
#                   행정구역       총인구수        세대수  세대당 인구     남자 인구수     여자 인구수  \
# 0  서울특별시  (1100000000)  9,532,428  4,422,587    2.16  4,630,630  4,901,798
#
#    남여 비율
# 0   0.94

# %% [markdown]
# ### 자료형 확인, 변환

# %%
# 자료형 확인
df.dtypes
# Out:
# 행정구역       object
# 총인구수       object
# 세대수        object
# 세대당 인구    float64
# 남자 인구수     object
# 여자 인구수     object
# 남여 비율     float64
# dtype: object

# %%
# 숫자형으로 변환
df['총인구수'] = df['총인구수'].str.replace(',','').astype('int64')

# %%
df['세대수'] = df['세대수'].str.replace(',','').astype('int64')

# %%
df['남자 인구수'] = df['남자 인구수'].str.replace(',','').astype('int64')

# %%
df['여자 인구수'] = df['여자 인구수'].str.replace(',','').astype('int64')

# %%
df.dtypes
# Out:
# 행정구역       object
# 총인구수        int64
# 세대수         int64
# 세대당 인구    float64
# 남자 인구수      int64
# 여자 인구수      int64
# 남여 비율     float64
# dtype: object

# %% [markdown]
# ## 시도별 서브셋 생성
# * `컬럼.str.contains(문자열)` : 문자열이 포함된 데이터 추출

# %%
df_sido = df[df['행정구역'].str.contains('00000000')].copy()
df_sido
# Out:
#                        행정구역      총인구수      세대수  세대당 인구   남자 인구수   여자 인구수  \
# 0       서울특별시  (1100000000)   9532428  4422587    2.16  4630630  4901798
# 452     부산광역시  (2600000000)   3356311  1541975    2.18  1642368  1713943
# 674     대구광역시  (2700000000)   2390721  1062993    2.25  1178486  1212235
# 826     인천광역시  (2800000000)   2945009  1294158    2.28  1474536  1470473
# 999     광주광역시  (2900000000)   1442454   643841    2.24   713483   728971
# 1102    대전광역시  (3000000000)   1454228   662615    2.19   725742   728486
# 1187    울산광역시  (3100000000)   1122566   481811    2.33   576723   545843
# 1249  세종특별자치시  (3600000000)    368276   151639    2.43   183879   184397
# 1273      경기도  (4100000000)  13549577  5820524    2.33  6820025  6729552
# 1882      강원도  (4200000000)   1537717   743798    2.07   774008   763709
# 2095     충청북도  (4300000000)   1596948   757980    2.11   810093   786855
# 2265     충청남도  (4400000000)   2118977   999286    2.12  1083133  1035844
# 2492     전라북도  (4500000000)   1789770   847406    2.11   890378   899392
# 2754     전라남도  (4600000000)   1834653   901203    2.04   923037   911616
# 3100     경상북도  (4700000000)   2627925  1273579    2.06  1324128  1303797
# 3469     경상남도  (4800000000)   3318161  1503397    2.21  1670394  1647767
# 3806  제주특별자치도  (5000000000)    676569   306741    2.21   339195   337374
#
#       남여 비율
# 0      0.94
# 452    0.96
# 674    0.97
# 826    1.00
# 999    0.98
# 1102   1.00
# 1187   1.06
# 1249   1.00
# 1273   1.01
# 1882   1.01
# 2095   1.03
# 2265   1.05
# 2492   0.99
# 2754   1.01
# 3100   1.02
# 3469   1.01
# 3806   1.01

# %% [markdown]
# * 시도명 컬럼 추가

# %%
df_sido['시도명'] = df_sido['행정구역'].str.split(' ').str[0]

# %%
df_sido.head(3)
# Out:
#                     행정구역     총인구수      세대수  세대당 인구   남자 인구수   여자 인구수  남여 비율  \
# 0    서울특별시  (1100000000)  9532428  4422587    2.16  4630630  4901798   0.94
# 452  부산광역시  (2600000000)  3356311  1541975    2.18  1642368  1713943   0.96
# 674  대구광역시  (2700000000)  2390721  1062993    2.25  1178486  1212235   0.97
#
#        시도명
# 0    서울특별시
# 452  부산광역시
# 674  대구광역시

# %% [markdown]
# # 시도별 인구수 시각화
# * 인구 수가 가장 많은 지역은 어디일까?
# * 인구 수가 가장 적은 지역은 어디일까?

# %% [markdown]
# ## 총 인구수로 데이터 정렬하기

# %%
df_sido = df_sido.sort_values('총인구수', ascending=False)
df_sido
# Out:
#                        행정구역      총인구수      세대수  세대당 인구   남자 인구수   여자 인구수  \
# 1273      경기도  (4100000000)  13549577  5820524    2.33  6820025  6729552
# 0       서울특별시  (1100000000)   9532428  4422587    2.16  4630630  4901798
# 452     부산광역시  (2600000000)   3356311  1541975    2.18  1642368  1713943
# 3469     경상남도  (4800000000)   3318161  1503397    2.21  1670394  1647767
# 826     인천광역시  (2800000000)   2945009  1294158    2.28  1474536  1470473
# 3100     경상북도  (4700000000)   2627925  1273579    2.06  1324128  1303797
# 674     대구광역시  (2700000000)   2390721  1062993    2.25  1178486  1212235
# 2265     충청남도  (4400000000)   2118977   999286    2.12  1083133  1035844
# 2754     전라남도  (4600000000)   1834653   901203    2.04   923037   911616
# 2492     전라북도  (4500000000)   1789770   847406    2.11   890378   899392
# 2095     충청북도  (4300000000)   1596948   757980    2.11   810093   786855
# 1882      강원도  (4200000000)   1537717   743798    2.07   774008   763709
# 1102    대전광역시  (3000000000)   1454228   662615    2.19   725742   728486
# 999     광주광역시  (2900000000)   1442454   643841    2.24   713483   728971
# 1187    울산광역시  (3100000000)   1122566   481811    2.33   576723   545843
# 3806  제주특별자치도  (5000000000)    676569   306741    2.21   339195   337374
# 1249  세종특별자치시  (3600000000)    368276   151639    2.43   183879   184397
#
#       남여 비율      시도명
# 1273   1.01      경기도
# 0      0.94    서울특별시
# 452    0.96    부산광역시
# 3469   1.01     경상남도
# 826    1.00    인천광역시
# 3100   1.02     경상북도
# 674    0.97    대구광역시
# 2265   1.05     충청남도
# 2754   1.01     전라남도
# 2492   0.99     전라북도
# 2095   1.03     충청북도
# 1882   1.01      강원도
# 1102   1.00    대전광역시
# 999    0.98    광주광역시
# 1187   1.06    울산광역시
# 3806   1.01  제주특별자치도
# 1249   1.00  세종특별자치시

# %% [markdown]
# ## 막대그래프로 시각화하기

# %% [markdown]
# ### matplotlib.pyplot으로 시각화하기

# %%
plt.rcParams['figure.figsize']=(15,5)

plt.bar(df_sido['시도명'], df_sido['총인구수'])
plt.xticks(rotation=90)
plt.title('2021년 10월 시도별 총 인구수', size=20)
plt.xlabel('시도명')
plt.ylabel('총인구수')
plt.grid(axis='y', ls=':')
plt.show()

# %% [markdown]
# ### seaborn으로 시각화하기

# %%
sns.barplot(data=df_sido, x='시도명', y='총인구수')
plt.title('2021년 10월 시도별 총 인구수', size=20)
plt.grid(axis='y', ls=':')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## 파이그래프로 시각화하기

# %%
plt.figure(facecolor='snow')
plt.pie(df_sido['총인구수'], labels=df_sido['시도명']
       ,autopct='%.1f%%', pctdistance=0.8, rotatelabels=True)
plt.title('2021년 10월 시도별 총 인구수', size=20)
plt.show()

# %% [markdown]
# # 시도별 세대당 인구수 시각화
# * 2중 y축 표시하기<br>
# `fig, ax1 = plt.subplots()`<br>
# `ax2 = ax1.twinx()`

# %%
df_sido
# Out:
#                        행정구역      총인구수      세대수  세대당 인구   남자 인구수   여자 인구수  \
# 1273      경기도  (4100000000)  13549577  5820524    2.33  6820025  6729552
# 0       서울특별시  (1100000000)   9532428  4422587    2.16  4630630  4901798
# 452     부산광역시  (2600000000)   3356311  1541975    2.18  1642368  1713943
# 3469     경상남도  (4800000000)   3318161  1503397    2.21  1670394  1647767
# 826     인천광역시  (2800000000)   2945009  1294158    2.28  1474536  1470473
# 3100     경상북도  (4700000000)   2627925  1273579    2.06  1324128  1303797
# 674     대구광역시  (2700000000)   2390721  1062993    2.25  1178486  1212235
# 2265     충청남도  (4400000000)   2118977   999286    2.12  1083133  1035844
# 2754     전라남도  (4600000000)   1834653   901203    2.04   923037   911616
# 2492     전라북도  (4500000000)   1789770   847406    2.11   890378   899392
# 2095     충청북도  (4300000000)   1596948   757980    2.11   810093   786855
# 1882      강원도  (4200000000)   1537717   743798    2.07   774008   763709
# 1102    대전광역시  (3000000000)   1454228   662615    2.19   725742   728486
# 999     광주광역시  (2900000000)   1442454   643841    2.24   713483   728971
# 1187    울산광역시  (3100000000)   1122566   481811    2.33   576723   545843
# 3806  제주특별자치도  (5000000000)    676569   306741    2.21   339195   337374
# 1249  세종특별자치시  (3600000000)    368276   151639    2.43   183879   184397
#
#       남여 비율      시도명
# 1273   1.01      경기도
# 0      0.94    서울특별시
# 452    0.96    부산광역시
# 3469   1.01     경상남도
# 826    1.00    인천광역시
# 3100   1.02     경상북도
# 674    0.97    대구광역시
# 2265   1.05     충청남도
# 2754   1.01     전라남도
# 2492   0.99     전라북도
# 2095   1.03     충청북도
# 1882   1.01      강원도
# 1102   1.00    대전광역시
# 999    0.98    광주광역시
# 1187   1.06    울산광역시
# 3806   1.01  제주특별자치도
# 1249   1.00  세종특별자치시

# %%
fig, ax1 = plt.subplots()
ax1.bar(df_sido['시도명'], df_sido['총인구수'], width=-0.4, align='edge', label='총인구수')
ax1.bar(df_sido['시도명'], df_sido['세대수'], width=0.4, align='edge', label='세대수')
ax1.legend(loc=(0.3, 0.8))
ax1.set_xlabel('시도명')
ax1.set_ylabel('총인구수,세대수')
plt.xticks(rotation=45)

ax2 = ax1.twinx()
ax2.plot(df_sido['시도명'], df_sido['세대당 인구'], 'k^-.', mfc='r', mec='r', label='세대당 인구')
ax2.legend(loc=(0.6, 0.85))
ax2.set_ylabel('세대당 인구')

ax2.set_title('2021년 10월 시도별 인구수, 세대수, 세대당 인구', size=20)

plt.show()

# %% [markdown]
# # 시도별 성별 인구수 시각화

# %%
df_sido.head(3)
# Out:
#                      행정구역      총인구수      세대수  세대당 인구   남자 인구수   여자 인구수  남여 비율  \
# 1273    경기도  (4100000000)  13549577  5820524    2.33  6820025  6729552   1.01
# 0     서울특별시  (1100000000)   9532428  4422587    2.16  4630630  4901798   0.94
# 452   부산광역시  (2600000000)   3356311  1541975    2.18  1642368  1713943   0.96
#
#         시도명
# 1273    경기도
# 0     서울특별시
# 452   부산광역시

# %%
fig, ax1 = plt.subplots()
ax1.bar(df_sido['시도명'], df_sido['남자 인구수'], width=-0.4, align='edge', color='skyblue', label='남자인구수')
ax1.bar(df_sido['시도명'], df_sido['여자 인구수'], width=0.4, align='edge', color='pink', label='여자인구수')
ax1.legend(loc=(0.2,0.8))
plt.xticks(rotation=90)

ax2 = ax1.twinx()
ax2.plot(df_sido['시도명'], df_sido['남여 비율'], 'b^-.', mfc='r',mec='r', label='남여비율')
ax2.legend(loc=(0.6,0.85))
ax2.axhline(1, color='k')
ax2.set_title('2021년 10월 남여인구수, 남여비율', size=20)

plt.show()

# %% [markdown]
# ## 성별 인구수 차이

# %% [markdown]
# ### 성별 인구수 차이 컬럼 생성
# * 내림차순으로 정렬

# %%
df_sido['남여인구수차이'] = df_sido['남자 인구수']-df_sido['여자 인구수']
df_sido = df_sido.sort_values('남여인구수차이', ascending=False)
df_sido
# Out:
#                        행정구역      총인구수      세대수  세대당 인구   남자 인구수   여자 인구수  \
# 1273      경기도  (4100000000)  13549577  5820524    2.33  6820025  6729552
# 2265     충청남도  (4400000000)   2118977   999286    2.12  1083133  1035844
# 1187    울산광역시  (3100000000)   1122566   481811    2.33   576723   545843
# 2095     충청북도  (4300000000)   1596948   757980    2.11   810093   786855
# 3469     경상남도  (4800000000)   3318161  1503397    2.21  1670394  1647767
# 3100     경상북도  (4700000000)   2627925  1273579    2.06  1324128  1303797
# 2754     전라남도  (4600000000)   1834653   901203    2.04   923037   911616
# 1882      강원도  (4200000000)   1537717   743798    2.07   774008   763709
# 826     인천광역시  (2800000000)   2945009  1294158    2.28  1474536  1470473
# 3806  제주특별자치도  (5000000000)    676569   306741    2.21   339195   337374
# 1249  세종특별자치시  (3600000000)    368276   151639    2.43   183879   184397
# 1102    대전광역시  (3000000000)   1454228   662615    2.19   725742   728486
# 2492     전라북도  (4500000000)   1789770   847406    2.11   890378   899392
# 999     광주광역시  (2900000000)   1442454   643841    2.24   713483   728971
# 674     대구광역시  (2700000000)   2390721  1062993    2.25  1178486  1212235
# 452     부산광역시  (2600000000)   3356311  1541975    2.18  1642368  1713943
# 0       서울특별시  (1100000000)   9532428  4422587    2.16  4630630  4901798
#
#       남여 비율      시도명  남여인구수차이
# 1273   1.01      경기도    90473
# 2265   1.05     충청남도    47289
# 1187   1.06    울산광역시    30880
# 2095   1.03     충청북도    23238
# 3469   1.01     경상남도    22627
# 3100   1.02     경상북도    20331
# 2754   1.01     전라남도    11421
# 1882   1.01      강원도    10299
# 826    1.00    인천광역시     4063
# 3806   1.01  제주특별자치도     1821
# 1249   1.00  세종특별자치시     -518
# 1102   1.00    대전광역시    -2744
# 2492   0.99     전라북도    -9014
# 999    0.98    광주광역시   -15488
# 674    0.97    대구광역시   -33749
# 452    0.96    부산광역시   -71575
# 0      0.94    서울특별시  -271168

# %% [markdown]
# ### 시각화

# %%
sns.barplot(data=df_sido, x='시도명', y='남여인구수차이')
plt.xticks(rotation=45)
plt.axhline(0, color='gray')
plt.title('2021년 10월 시도별 남여 인구수 차이', size=20)
plt.ylabel('남자인구수-여자인구수')
plt.show()

# %% [markdown]
# # 서울시 구별/동별 인구수 시각화

# %% [markdown]
# ## 서울시 구별 인구수 시각화

# %% [markdown]
# ### 서브셋 생성

# %%
df_seoul = df[df['행정구역'].str.find('구 (11')>0].copy()

# %%
df_seoul['구'] = df_seoul['행정구역'].str.split(' ').str[1]

# %%
df_seoul = df_seoul.sort_values('총인구수', ascending=False)
df_seoul
# Out:
#                         행정구역    총인구수     세대수  세대당 인구  남자 인구수  여자 인구수  남여 비율  \
# 404   서울특별시 송파구 (1171000000)  659239  282185    2.34  317773  341466   0.93
# 256   서울특별시 강서구 (1150000000)  575370  270623    2.13  277041  298329   0.93
# 381   서울특별시 강남구 (1168000000)  533878  234533    2.28  255473  278405   0.92
# 168   서울특별시 노원구 (1135000000)  512129  217201    2.36  246650  265479   0.93
# 340   서울특별시 관악구 (1162000000)  487357  276315    1.76  244844  242513   1.01
# 188   서울특별시 은평구 (1138000000)  473369  214126    2.21  226514  246855   0.92
# 432   서울특별시 강동구 (1174000000)  463752  201428    2.30  227755  235997   0.97
# 237   서울특별시 양천구 (1147000000)  448634  181434    2.47  219862  228772   0.96
# 118   서울특별시 성북구 (1129000000)  432081  195126    2.21  208308  223773   0.93
# 362   서울특별시 서초구 (1165000000)  415083  171083    2.43  198470  216613   0.92
# 277   서울특별시 구로구 (1153000000)  397330  180541    2.20  195909  201421   0.97
# 101   서울특별시 중랑구 (1126000000)  388218  185505    2.09  191601  196617   0.97
# 324   서울특별시 동작구 (1159000000)  386246  184598    2.09  186863  199383   0.94
# 305  서울특별시 영등포구 (1156000000)  377524  186585    2.02  186390  191134   0.98
# 220   서울특별시 마포구 (1144000000)  369695  179571    2.06  173985  195710   0.89
# 70    서울특별시 광진구 (1121500000)  340814  167559    2.03  164425  176389   0.93
# 86   서울특별시 동대문구 (1123000000)  337538  167754    2.01  166842  170696   0.98
# 153   서울특별시 도봉구 (1132000000)  318299  138655    2.30  154970  163329   0.95
# 205  서울특별시 서대문구 (1141000000)  305840  143723    2.13  146208  159632   0.92
# 139   서울특별시 강북구 (1130500000)  300278  144501    2.08  146240  154038   0.95
# 52    서울특별시 성동구 (1120000000)  287174  134517    2.13  139958  147216   0.95
# 294   서울특별시 금천구 (1154500000)  230740  116935    1.97  116588  114152   1.02
# 35    서울특별시 용산구 (1117000000)  223713  111067    2.01  107607  116106   0.93
# 1     서울특별시 종로구 (1111000000)  145346   73613    1.97   70552   74794   0.94
# 19     서울특별시 중구 (1114000000)  122781   63409    1.94   59802   62979   0.95
#
#         구
# 404   송파구
# 256   강서구
# 381   강남구
# 168   노원구
# 340   관악구
# 188   은평구
# 432   강동구
# 237   양천구
# 118   성북구
# 362   서초구
# 277   구로구
# 101   중랑구
# 324   동작구
# 305  영등포구
# 220   마포구
# 70    광진구
# 86   동대문구
# 153   도봉구
# 205  서대문구
# 139   강북구
# 52    성동구
# 294   금천구
# 35    용산구
# 1     종로구
# 19     중구

# %% [markdown]
# ### 시각화

# %%
sns.barplot(data=df_seoul, x='구', y='총인구수')
plt.title('2021년 10월 서울시 구별 총 인구수', size=20)
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 동별 인구수 시각화
# * 송파구 동별 인구수 시각화

# %% [markdown]
# ### 서브셋 만들기

# %%
df_song = df[df['행정구역'].str.find('동(1171')>0].copy()

# %%
df_song['동'] = df_song['행정구역'].str.split(' ').str[2].str.split('(').str[0]
df_song
# Out:
#                            행정구역   총인구수    세대수  세대당 인구  남자 인구수  여자 인구수  남여 비율  \
# 405  서울특별시 송파구 풍납1동(1171051000)  12989   6027    2.16    6355    6634   0.96
# 406  서울특별시 송파구 풍납2동(1171052000)  24977  11019    2.27   11873   13104   0.91
# 407  서울특별시 송파구 거여1동(1171053100)  12615   5648    2.23    6367    6248   1.02
# 408  서울특별시 송파구 거여2동(1171053200)  18811   8153    2.31    9252    9559   0.97
# 409  서울특별시 송파구 마천1동(1171054000)  19005   8785    2.16    9718    9287   1.05
# 410  서울특별시 송파구 마천2동(1171055000)  18845   8726    2.16    9587    9258   1.04
# 411  서울특별시 송파구 방이1동(1171056100)  15771   6263    2.52    7603    8168   0.93
# 412  서울특별시 송파구 방이2동(1171056200)  26657  15316    1.74   12388   14269   0.87
# 413   서울특별시 송파구 오륜동(1171056600)  18063   5929    3.05    8857    9206   0.96
# 414   서울특별시 송파구 오금동(1171057000)  38637  15663    2.47   18739   19898   0.94
# 415  서울특별시 송파구 송파1동(1171058000)  23987  12264    1.96   11205   12782   0.88
# 416  서울특별시 송파구 송파2동(1171059000)  19219   7235    2.66    9239    9980   0.93
# 417   서울특별시 송파구 석촌동(1171060000)  31669  16904    1.87   15120   16549   0.91
# 418   서울특별시 송파구 삼전동(1171061000)  30443  16078    1.89   14341   16102   0.89
# 419  서울특별시 송파구 가락본동(1171062000)  26387  11877    2.22   13063   13324   0.98
# 420  서울특별시 송파구 가락1동(1171063100)  27316   9799    2.79   13238   14078   0.94
# 421  서울특별시 송파구 가락2동(1171063200)  32457  12460    2.60   15945   16512   0.97
# 422  서울특별시 송파구 문정1동(1171064100)  20092   8487    2.37    9949   10143   0.98
# 423  서울특별시 송파구 문정2동(1171064200)  28923  15708    1.84   13304   15619   0.85
# 424   서울특별시 송파구 장지동(1171064600)  29458  12066    2.44   14248   15210   0.94
# 425   서울특별시 송파구 위례동(1171064700)  37697  12241    3.08   18331   19366   0.95
# 426  서울특별시 송파구 잠실본동(1171065000)  28026  15435    1.82   13259   14767   0.90
# 427  서울특별시 송파구 잠실2동(1171067000)  35210  11633    3.03   16842   18368   0.92
# 428  서울특별시 송파구 잠실3동(1171068000)  34389  11930    2.88   16353   18036   0.91
# 429  서울특별시 송파구 잠실4동(1171069000)  21252   7268    2.92   10189   11063   0.92
# 430  서울특별시 송파구 잠실6동(1171071000)  16765   5879    2.85    7940    8825   0.90
# 431  서울특별시 송파구 잠실7동(1171072000)   9579   3392    2.82    4468    5111   0.87
#
#         동
# 405  풍납1동
# 406  풍납2동
# 407  거여1동
# 408  거여2동
# 409  마천1동
# 410  마천2동
# 411  방이1동
# 412  방이2동
# 413   오륜동
# 414   오금동
# 415  송파1동
# 416  송파2동
# 417   석촌동
# 418   삼전동
# 419  가락본동
# 420  가락1동
# 421  가락2동
# 422  문정1동
# 423  문정2동
# 424   장지동
# 425   위례동
# 426  잠실본동
# 427  잠실2동
# 428  잠실3동
# 429  잠실4동
# 430  잠실6동
# 431  잠실7동

# %%
df_song = df_song.sort_values('총인구수', ascending=False)

# %% [markdown]
# ### 시각화

# %%
sns.barplot(data=df_song, x='동', y='총인구수')
plt.title('2021년 10월 송파구 동별 총 인구수', size=20)
plt.xticks(rotation=45)
plt.show()
